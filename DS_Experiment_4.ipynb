# %% [markdown]
# <a href="https://colab.research.google.com/github/ashel1307/Artificial_Intelligence_Lab_SE_A_55/blob/master/DS_Experiment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probability and Statistics using Python:**
# # (Libraries Required: numpy, scipy.stats, matplotlib)

# %% [markdown]
# # 1. Generate a normal distribution and plot its histogram

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Given parameters
mu = 0        # Mean
sigma = 1     # Standard Deviation

# Create an array of x values
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 20)

print("X Values : ")
print(x)
# Calculate the PDF using scipy
pdf = norm.pdf(x, mu, sigma)

# Plot the normal distribution
plt.figure()
plt.plot(x, pdf)
plt.title("Normal Distribution (μ = {}, σ = {})".format(mu, sigma))
plt.xlabel("X values")
plt.ylabel("Probability Density")
plt.grid()
plt.show()
# Out:
# X Values :
# [-4.         -3.57894737 -3.15789474 -2.73684211 -2.31578947 -1.89473684
#  -1.47368421 -1.05263158 -0.63157895 -0.21052632  0.21052632  0.63157895
#   1.05263158  1.47368421  1.89473684  2.31578947  2.73684211  3.15789474
#   3.57894737  4.        ]

# %% [markdown]
# # 2. Compute mean, median, variance, and standard deviation for a dataset.

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Sample dataset
data = np.array([12, 15, 14, 10, 18, 20, 17, 16, 19, 11])

# Descriptive Statistics
mean = np.mean(data)
median = np.median(data)
variance = np.var(data)
std_deviation = np.std(data)

# Using SciPy (for verification of mean)
mean_scipy = stats.tmean(data)

# Print results
print("Dataset:", data)
print("Mean (μ):", mean)
print("Median:", median)
print("Variance (σ²):", variance)
print("Standard Deviation (σ):", std_deviation)

# Plotting the data
plt.figure()
plt.hist(data, bins=5)
plt.axvline(mean, linestyle='dashed')
plt.axvline(median, linestyle='dotted')

plt.title("Descriptive Statistics Visualization")
plt.xlabel("Data Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# Dataset: [12 15 14 10 18 20 17 16 19 11]
# Mean (μ): 15.2
# Median: 15.5
# Variance (σ²): 10.559999999999999
# Standard Deviation (σ): 3.249615361854384

# %% [markdown]
# # 3. Simulate a coin toss experiment and compute probabilities.

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Number of coin tosses
n_tosses = 1000

# Simulate coin tosses (0 = Tail, 1 = Head)
tosses = np.random.choice([0, 1], size=n_tosses)

# Count number of Heads and Tails
heads = np.sum(tosses)
tails = n_tosses - heads

# Empirical probabilities
p_heads = heads / n_tosses
p_tails = tails / n_tosses

# Theoretical probabilities using SciPy (Binomial distribution)
theoretical_prob = stats.binom.pmf(heads, n_tosses, 0.5)

# Print results
print("Total Tosses:", n_tosses)
print("Number of Heads:", heads)
print("Number of Tails:", tails)
print("Empirical P(Head):", p_heads)
print("Empirical P(Tail):", p_tails)

# Plot results
labels = ['Head', 'Tail']
counts = [heads, tails]

plt.figure()
plt.bar(labels, counts)
plt.title("Coin Toss Simulation (n = {})".format(n_tosses))
plt.xlabel("Outcome")
plt.ylabel("Frequency")
plt.show()
# Out:
# Total Tosses: 1000
# Number of Heads: 492
# Number of Tails: 508
# Empirical P(Head): 0.492
# Empirical P(Tail): 0.508
